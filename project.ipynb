# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("job_salary_prediction_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   job_title         250000 non-null  str
#  1   experience_years  250000 non-null  int64
#  2   education_level   250000 non-null  str
#  3   skills_count      250000 non-null  int64
#  4   industry          250000 non-null  str
#  5   company_size      250000 non-null  str
#  6   location          250000 non-null  str
#  7   remote_work       250000 non-null  str
#  8   certifications    250000 non-null  int64
#  9   salary            250000 non-null  int64
# dtypes: int64(4), str(6)
# memory usage: 19.1 MB

# %%
df['job_title'].unique()
# Out:
# <StringArray>
# [              'AI Engineer',              'Data Analyst',
#         'Frontend Developer',          'Business Analyst',
#            'Product Manager',         'Backend Developer',
#  'Machine Learning Engineer',           'DevOps Engineer',
#          'Software Engineer',     'Cybersecurity Analyst',
#             'Data Scientist',            'Cloud Engineer']
# Length: 12, dtype: str

# %%
df['experience_years'].describe()
df1 = df.sample(5000)

# %%
sns.histplot(df1['experience_years'],kde = True)
# Out:
# <Axes: xlabel='experience_years', ylabel='Count'>

# %%
sns.boxplot(df['experience_years'])
# Out:
# <Axes: ylabel='experience_years'>

# %%
sns.barplot(x = 'experience_years',y='salary',data = df1)
# Out:
# <Axes: xlabel='experience_years', ylabel='salary'>

# %%
df1['education_level'].value_counts()
# Out:
# education_level
# Bachelor       1028
# PhD            1026
# Diploma         998
# High School     979
# Master          969
# Name: count, dtype: int64

# %%
sns.barplot(x='education_level', y='salary', data=df)
# Out:
# <Axes: xlabel='education_level', ylabel='salary'>

# %%
df1['skills_count'].value_counts()
# Out:
# skills_count
# 6     291
# 14    284
# 1     276
# 18    273
# 8     268
# 9     267
# 10    266
# 16    264
# 19    263
# 2     263
# 4     263
# 12    262
# 5     260
# 15    258
# 13    256
# 3     256
# 7     253
# 17    239
# 11    238
# Name: count, dtype: int64

# %%
sns.histplot(df1['skills_count'],kde=True)
# Out:
# <Axes: xlabel='skills_count', ylabel='Count'>

# %%
sns.boxplot(df1['skills_count'])
# Out:
# <Axes: ylabel='skills_count'>

# %%
sns.barplot(x='skills_count',y='salary',data=df1)
# Out:
# <Axes: xlabel='skills_count', ylabel='salary'>
